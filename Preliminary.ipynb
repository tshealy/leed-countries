# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
data_2009 = pd.read_pickle("original_data/2009_full_score_projects_final.pkl")

# %%
data_22 = pd.read_pickle("original_data/2_2_full_score_projects_final.pkl")

# %%
data_21 = pd.read_pickle("original_data/scores_2_1.pkl")

# %%
data_21.shape
# Out:
# (678, 116)

# %%
data_2009_country = data_2009.groupby('country').count()

# %%
data_2009_country
# Out:
#          ssc1  ssc2  ssc3  ssc4_1  ssc4_2  ssc4_3  ssc4_4  ssc5_1  ssc5_2  \
# country
# BR          5     5     5       5       5       5       5       5       5
# GB          1     1     1       1       1       1       1       1       1
# IT          3     3     3       3       3       3       3       3       3
# US       2492  2492  2492    2492    2492    2492    2492    2492    2492
#
#          ssc6_1        ...          zip_code  leed_version  points_achieved  \
# country                ...
# BR            5        ...                 5             5                5
# GB            1        ...                 1             1                1
# IT            3        ...                 3             3                3
# US         2492        ...              2492          2492             2492
#
#          certification_level  certification_date  owner_types  \
# country
# BR                         5                   5            5
# ...

# %%
data_2009.head()
# Out:
#             ssc1  ssc2  ssc3  ssc4_1  ssc4_2  ssc4_3  ssc4_4  ssc5_1  ssc5_2  \
# project_id
# 1000000143     1     5     0       6       0       0       2       0       1
# 1000000174     0     0     0       6       1       0       0       0       1
# 1000000194     1     5     0       0       1       3       2       0       0
# 1000000199     1     0     0       0       1       3       0       0       1
# 1000000222     1     5     0       6       1       3       2       0       0
#
#             ssc6_1        ...          country   leed_version  \
# project_id                ...
# 1000000143       1        ...               US  LEED-NC v2009
# 1000000174       0        ...               US  LEED-NC v2009
# 1000000194       0        ...               US  LEED-NC v2009
# 1000000199       0        ...               US  LEED-NC v2009
# 1000000222       0        ...               US  LEED-NC v2009
#
#             points_achieved  certification_level  certification_date  \
# project_id
# ...

# %%
print(data_21.columns[:20])
# Out:
# Index(['id', 'ssc1', 'ssc2', 'ssc3', 'ssc4_1', 'ssc4_2', 'ssc4_3', 'ssc4_4',
#        'ssc5_1', 'ssc5_2', 'ssc6_1', 'ssc6_2', 'ssc7_1', 'ssc7_2', 'ssc8',
#        'wec1_1', 'wec1_2', 'wec2', 'wec3_1', 'wec3_2'],
#       dtype='object')

# %%
all_data = pd.read_csv("original_data/all_projects_dataframe.csv")
# Out:
# /Users/trippshealy/Gdrive/research/leed_countries/.direnv/python-3.4.3/lib/python3.4/site-packages/pandas/io/parsers.py:1170: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
all_data = all_data[all_data['Isconfidential'] == 'No']

# %%
all_data.groupby("LEEDSystemVersionDisplayName").count()
# Out:
#                                              ID  Isconfidential  ProjectName  \
# LEEDSystemVersionDisplayName
# LEED FOR SCHOOLS v2009                     1271            1271         1271
# LEED For Homes Multi Family Low-Rise       2847            2847         2846
# LEED For Homes Multi Family Mid-Rise        775             775          775
# LEED For Homes Single Family              21938           21938        21938
# LEED India 2011 CS                            1               1            1
# LEED India 2011 NC                            4               4            4
# LEED Italia NC 2009                          67              67           67
# LEED Master Site BD+C                         1               1            1
# LEED V4 BD+C: HOLR                           12              12           12
# LEED V4 BD+C: HOMR                            1               1            1
# LEED for Retail (CI) Pilot                  790             790          790
# ...

# %%
all_data.head(20)
# Out:
#           ID Isconfidential                               ProjectName  \
# 0   10000000             No                      PNC Firstside Center
# 2   10000002             No                  Bethel Commercial Center
# 4   10000004             No   The Chicago Center for Green Technology
# 5   10000005             No               625 Broadway Office Complex
# 6   10000006             No                   Seattle Central Library
# 7   10000007             No   NRDC Southern California Office, Robert
# 8   10000008             No             Renovation of the Motherhouse
# 9   10000009             No                    Sabre Corporate Campus
# 10  10000010             No       Plaza Building, Desert Vista Campus
# 11  10000011             No    Whitehead Biomedical Research Building
# 13  10000013             No   North Cascades Environ. Learning Center
# 15  10000015             No                            Student Center
# ...

# %%
#all data for 2009
all_2009 = all_data[all_data["LEEDSystemVersionDisplayName"] == "LEED-NC v2009"]

# %%
all_2009.dropna().head(40)
# Out:
#                ID Isconfidential                              ProjectName  \
# 53494  1000000086             No      AUO SunPower Central Admin Building
# 53499  1000000104             No                               Katharinum
# 53515  1000000143             No  Mary Bird Perkins Cancer Center at TGMC
# 53535  1000000174             No     Indiana Tech Seitz Center Renovation
# 53548  1000000194             No                            Kyra InfoTech
# 53551  1000000199             No          Public Safety Training Facility
# 53567  1000000222             No      Univ of Texas Liberal Arts Building
# 53569  1000000224             No             Collinwood Recreation Center
# 53584  1000000244             No                     The Franklin Theatre
# 53596  1000000262             No                         Fire Station No7
# 53619  1000000292             No                       Maxella Apartments
# 53625  1000000301             No    Davis Hall Restoration and Renovation
# ...

# %%
all_2009 = all_2009.dropna()
all_2009.PointsAchieved = all_2009.PointsAchieved.astype(float)
print(len(all_2009[all_2009["PointsAchieved"] < 40]))
# Out:
# 7

# %%
all_data_country = all_data.groupby('Country').count()

# %%
all_2009_country = all_2009.groupby('Country').count()

# %%
country_list_2009 = all_2009_country[all_2009_country['ID'] > 20].index

# %%
len(country_list_2009)
# Out:
# 27

# %%
combo_list_2009 = itertools.combinations(country_list_2009, 2)

# %%
list(combo_list_2009)
# Out:
# [('AE', 'AR'),
#  ('AE', 'BD'),
#  ('AE', 'BR'),
#  ('AE', 'CL'),
#  ('AE', 'CN'),
#  ('AE', 'CO'),
#  ('AE', 'CR'),
#  ('AE', 'DE'),
#  ('AE', 'ES'),
#  ('AE', 'FI'),
#  ('AE', 'FR'),
#  ('AE', 'IN'),
#  ('AE', 'KR'),
#  ('AE', 'LK'),
#  ('AE', 'MX'),
#  ('AE', 'MY'),
#  ('AE', 'PA'),
#  ('AE', 'PH'),
#  ('AE', 'QA'),
#  ('AE', 'RU'),
#  ('AE', 'SA'),
#  ('AE', 'SE'),
#  ('AE', 'TH'),
#  ('AE', 'TR'),
#  ('AE', 'TW'),
#  ('AE', 'US'),
#  ('AR', 'BD'),
#  ('AR', 'BR'),
#  ('AR', 'CL'),
#  ('AR', 'CN'),
#  ('AR', 'CO'),
#  ('AR', 'CR'),
#  ('AR', 'DE'),
#  ('AR', 'ES'),
#  ('AR', 'FI'),
#  ('AR', 'FR'),
#  ('AR', 'IN'),
#  ('AR', 'KR'),
#  ('AR', 'LK'),
#  ('AR', 'MX'),
#  ('AR', 'MY'),
#  ('AR', 'PA'),
#  ('AR', 'PH'),
#  ('AR', 'QA'),
#  ('AR', 'RU'),
#  ('AR', 'SA'),
#  ('AR', 'SE'),
#  ('AR', 'TH'),
#  ('AR', 'TR'),
#  ('AR', 'TW'),
#  ('AR', 'US'),
#  ('BD', 'BR'),
#  ('BD', 'CL'),
#  ('BD', 'CN'),
#  ('BD', 'CO'),
#  ('BD', 'CR'),
#  ('BD', 'DE'),
#  ('BD', 'ES'),
# ...

# %%
one = all_2009[all_2009['Country'] == 'AE'].PointsAchieved.dropna().astype(float)
two = all_2009[all_2009['Country'] == 'AR'].PointsAchieved.dropna().astype(float)
t, p = ttest_ind(one, two, equal_var=False)
print(t,p)
# Out:
# -1.03301698212 0.313099322783

# %%
stat_difference = []
for i in combo_list:
    a, b = i
    one = all_2009[all_2009['Country'] == a].PointsAchieved.dropna().astype(float)
    two = all_2009[all_2009['Country'] == b].PointsAchieved.dropna().astype(float)
    t, p = ttest_ind(one, two, equal_var=False)
    if p <= 0.001:
        stat_difference.append([a,b])

# %%
stat_difference
# Out:
# [['AE', 'LK'],
#  ['AE', 'SE'],
#  ['BD', 'CR'],
#  ['BR', 'CR'],
#  ['BR', 'LK'],
#  ['BR', 'SE'],
#  ['CL', 'LK'],
#  ['CL', 'SE'],
#  ['CL', 'SG'],
#  ['CN', 'CR'],
#  ['CN', 'SE'],
#  ['CN', 'US'],
#  ['CR', 'DE'],
#  ['CR', 'ES'],
#  ['CR', 'FI'],
#  ['CR', 'KR'],
#  ['CR', 'LK'],
#  ['CR', 'MX'],
#  ['CR', 'SE'],
#  ['CR', 'SG'],
#  ['CR', 'TR'],
#  ['CR', 'TW'],
#  ['DE', 'US'],
#  ['ES', 'US'],
#  ['LK', 'PH'],
#  ['LK', 'QA'],
#  ['LK', 'US'],
#  ['PH', 'SE'],
#  ['QA', 'SE'],
#  ['SE', 'TR'],
#  ['SE', 'US']]

# %%
country_list = all_data_country[all_data_country['ID'] > 50].index

# %%
country_list
# Out:
# Index(['AE', 'AR', 'BD', 'BR', 'CA', 'CL', 'CN', 'CO', 'CR', 'CZ', 'DE', 'ES',
#        'FI', 'FR', 'GB', 'GU', 'HK', 'IN', 'IT', 'JP', 'KR', 'LK', 'MX', 'MY',
#        'PA', 'PE', 'PH', 'PL', 'QA', 'RU', 'SA', 'SE', 'SG', 'TH', 'TR', 'TW',
#        'US'],
#       dtype='object', name='Country')

# %%
import itertools

# %%
combo_list = itertools.combinations(country_list, 2)

# %%
combo_list = list(combo_list)

# %%
len(country_list)
# Out:
# 37

# %%
all_data[all_data['Country'] == 'AE'].PointsAchieved.dropna()
# Out:
# 3845     55
# 3851     43
# 3853     40
# 6167     37
# 6727     32
# 6810     35
# 6811     29
# 6812     32
# 8882     35
# 9842     43
# 10938    24
# 12167    34
# 12685    37
# 12687    33
# 13127    36
# 13378    44
# 13379    40
# 13453    41
# 13461    40
# 13466    40
# 13468    53
# 13471    37
# 13472    37
# 13473    42
# 13474    48
# 13500    36
# 13534    40
# 13535    38
# 13540    35
# 13544    39
#          ..
# 70419    60
# 70466    61
# 70761    60
# 71296    71
# 72064    59
# 72395    30
# 72444    54
# 73733    80
# 74302     6
# 75164    81
# 75809    41
# 76991    43
# 77139    64
# 77234    61
# 77416    62
# 77815    59
# 77851    67
# 78574    42
# 80027    47
# 80040    45
# 80084     7
# 80321    25
# 81655    48
# 81974    65
# 82251    68
# 82718    72
# 82865    62
# 83145    26
# 85992    87
# 89138    38
# Name: PointsAchieved, dtype: object

# %%
##t-test function
from scipy.stats import ttest_ind

# %%
stat_difference = []
for i in combo_list:
    a, b = i
    one = all_data[all_data['Country'] == a].PointsAchieved.dropna()
    two = all_data[all_data['Country'] == b].PointsAchieved.dropna()
    t, p = ttest_ind(one, two, equal_var=False)
    if p <= 0.05:
        stat_difference.append([a,b])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-492555372b51> in <module>()
#       4     one = all_data[all_data['Country'] == a].PointsAchieved.dropna()
#       5     two = all_data[all_data['Country'] == b].PointsAchieved.dropna()
# ----> 6     t, p = ttest_ind(one, two, equal_var=False)
#       7     if p <= 0.05:
#       8         stat_difference.append([a,b])
#
# /Users/trippshealy/Gdrive/research/leed_countries/.direnv/python-3.4.3/lib/python3.4/site-packages/scipy/stats/stats.py in ttest_ind(a, b, axis, equal_var)
#    3544         return Ttest_indResult(np.nan, np.nan)
#    3545
# -> 3546     v1 = np.var(a, axis, ddof=1)
#    3547     v2 = np.var(b, axis, ddof=1)
#    3548     n1 = a.shape[axis]
#
# ...
